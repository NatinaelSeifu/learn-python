# %% [markdown]
# * Data types are basic building blocks when constructing larger pieces of code.
# * some of them are "int, float, str, list, dict, etc ..."

# %% [markdown]
# * lets start by python numbers
# * An intiger has no decimals in it, whereas a floating point number can display digits past the decimal point

# %%
# Addition
2+2
# Out:
# 4

# %%
# multiplication 
2*3
# Out:
# 6

# %%
# division
8/3
# Out:
# 2.6666666666666665

# %% [markdown]
# * Module - mod is finding a remainder

# %%
# module 
7%4
# Out:
# 3

# %%
#squaring 
2**3
# Out:
# 8

# %%
# Follows Bodmass rule
(2+10) * (10+3)
# Out:
# 156

# %% [markdown]
# All this happens because python 3 performs those actions by default.
